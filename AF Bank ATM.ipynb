# %%
print("Welcome TO MF Bank ATM")
restart = ("Y")
chances = 3
balance = 100000

while chances >=0:
    pin = int(input("Enter Your 4 Digits Pin"))
    if pin == (1998):
        print("You Enter The Pin Correctly")
        print("Press 1 Fir Your Balance Inquiry")
        print("Press 2 to make a Withdraw")
        print("Press 3 to Deposit")
        print("Press 4 to Take your card back")
        
        while restart not in ('n', "NO", 'no', "N"):
            print("You Enter The Pin Correctly")
            print("Press 1 Fir Your Balance Inquiry")
            print("Press 2 to make a Withdraw")
            print("Press 3 to Pay in")
            print("Press 4 to Take your card back")
            
            option = int(input("What would you like to choose"))
            
            if option == 1:
                print("Your balance is " , balance)
                restart = input("Whould you like to go back")
                if restart not in ('n', "NO", 'no', "N"):
                    print("Thank you")
                    break
            elif option == 2:
                withdrawl = float(input("You can Draw Only Cash of Mutiple of 500 "))
                if withdrawl/ 500 == 0:
                    balance = balance - withdrawl
                    print("Your Balance is " , balance)
                    restart = input("Whould you like to go back")
                    if restart not in ('n', "NO", 'no', "N"):
                        print("Thank you")
                        break
                        
                elif withdrwal /500 != 0:
                    print("please Enter The Valid Amount")
                    restart = ("Y")
                elif withdrawl == 1:
                    withdrawl = float(input("Please Enter The Desired Amount"))
                    
            elif option == 3:
                deposit = float(input("Enter The Amount of Multiple of 500"))
                balance = balance + deposit
                print("Your Balance is " , balance)
                restart = input("Would you like to go back?")
                restart = input("Whould you like to go back")
                if restart not in ('n', "NO", 'no', "N"):
                    print("Thank you")
                    break
                    
            elif option == 4:
                print("Please wait for a sec while Your card is Returned")
                print("Thanks For Visiting MF Bank ATM ")
                break
                
            else:
                print("Please Enter The valid Number :")
                restart = ("Y")
    elif pin != (1998):
        print("Incorrect Password ")
        chances = chances - 1
        if chances == 3:
            print("No More Tries")
            break
